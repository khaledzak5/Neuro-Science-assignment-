# %%
#<----- Click this play button to setup MocapNET v4!

#This is the Total Capture version that handles body, hands, gaze, face!
#It also has been rewritten from scratch in Python for your convenience.
#If you deploy this on your PC, run : jupyter notebook mocapnet4.ipynb
#   and remove --collab from the setup.sh invocation 2 lines below..!
import os
if (os.path.isfile("MocapNET.py")):
    # !git pull
    exit
# !git clone -b mnet4 https://github.com/FORTH-ModelBasedTracker/MocapNET.git
# !MocapNET/src/python/mnet4/setup.sh --collab
os.chdir("MocapNET/src/python/mnet4")
print("MocapNET setup is finished, you can run the next cell now..")
# Out:
# fatal: destination path 'MocapNET' already exists and is not an empty directory.
# Checking for build-essential: install ok installed
# Checking for python3-venv: install ok installed
# Checking for python3-pip: install ok installed
# Checking for freeglut3-dev: install ok installed
# Checking for libglew-dev: install ok installed
# Checking for protobuf-compiler: install ok installed
# Checking for libprotobuf-dev: install ok installed
# Checking for libavdevice-dev: install ok installed
# Collab mode!
# Performing python package installation without a virtual environment
# ln: failed to create symbolic link '/content/mnet4/mnet4': File exists
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# freeglut3-dev is already the newest version (2.8.1-6).
# libglew-dev is already the newest version (2.2.0-4).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# RGBDAcquisition appears to already exist ..
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (0.60.0)
# Requirement already satisfied: tensorboard_plugin_profile in /usr/local/lib/python3.11/dist-packages (2.19.1)
# Requirement already satisfied: tensorflow-model-optimization in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: tf2onnx in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.21.0)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.11/dist-packages (0.10.8)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: gviz-api>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard_plugin_profile) (1.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.11/dist-packages (from tensorboard_plugin_profile) (3.1.3)
# Requirement already satisfied: etils>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.0.0->tensorboard_plugin_profile) (1.12.2)
# Requirement already satisfied: cheroot>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard_plugin_profile) (10.0.1)
# Requirement already satisfied: fsspec>=2024.10.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2025.3.2)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-model-optimization) (0.1.9)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: more-itertools>=2.6 in /usr/local/lib/python3.11/dist-packages (from cheroot>=10.0.1->tensorboard_plugin_profile) (10.6.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.11/dist-packages (from cheroot>=10.0.1->tensorboard_plugin_profile) (4.1.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.0.0->tensorboard_plugin_profile) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]>=1.0.0->tensorboard_plugin_profile) (3.21.0)
# Requirement already satisfied: gcsfs in /usr/local/lib/python3.11/dist-packages (from fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2025.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=0.11.15->tensorboard_plugin_profile) (3.0.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (3.11.15)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (from gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.2.1)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (from gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.19.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (6.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.18.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.24.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.69.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->fsspec[gcs]>=2024.10.0->tensorboard_plugin_profile) (3.2.2)
# --2025-04-06 00:25:48--  http://ammar.gr/mocapnet/mnet4/mnet4_-314.zip
# Resolving ammar.gr (ammar.gr)... 139.91.185.16
# Connecting to ammar.gr (ammar.gr)|139.91.185.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138288918 (132M) [application/zip]
# Saving to: ‘mnet4_-314.zip’
#
# mnet4_-314.zip      100%[===================>] 131.88M  13.1MB/s    in 12s
#
# 2025-04-06 00:26:00 (11.3 MB/s) - ‘mnet4_-314.zip’ saved [138288918/138288918]
#
# Archive:  mnet4_-314.zip
#  extracting: step1_lhand_all/fingerprint.pb
#   inflating: step1_lhand_all/keras_metadata.pb
#   inflating: step1_lhand_all/lhand_configuration.json
#   inflating: step1_lhand_all/model.onnx
#   inflating: step1_lhand_all/model.tflite
#   inflating: step1_lhand_all/neuralNetworkInputs.list
#   inflating: step1_lhand_all/neuralNetworkJoints.list
#   inflating: step1_lhand_all/neuralNetworkOutputs.list
#   inflating: step1_lhand_all/outputMaxima.csv
#   inflating: step1_lhand_all/outputMinima.csv
#   inflating: step1_lhand_all/outputOffsets.csv
#   inflating: step1_lhand_all/outputScalars.csv
#   inflating: step1_lhand_all/outputScalarsFraction.csv
#   inflating: step1_lhand_all/saved_model.pb
#   inflating: step1_lhand_all/summary.html
#  extracting: step1_lowerbody_all/fingerprint.pb
#   inflating: step1_lowerbody_all/keras_metadata.pb
#   inflating: step1_lowerbody_all/lowerbody_configuration.json
#   inflating: step1_lowerbody_all/model.onnx
#   inflating: step1_lowerbody_all/model.tflite
#   inflating: step1_lowerbody_all/neuralNetworkInputs.list
#   inflating: step1_lowerbody_all/neuralNetworkJoints.list
#   inflating: step1_lowerbody_all/neuralNetworkOutputs.list
#   inflating: step1_lowerbody_all/outputMaxima.csv
#   inflating: step1_lowerbody_all/outputMinima.csv
#   inflating: step1_lowerbody_all/outputOffsets.csv
#   inflating: step1_lowerbody_all/outputScalars.csv
#   inflating: step1_lowerbody_all/outputScalarsFraction.csv
#   inflating: step1_lowerbody_all/saved_model.pb
#   inflating: step1_lowerbody_all/summary.html
#  extracting: step1_mouth_all/fingerprint.pb
#   inflating: step1_mouth_all/keras_metadata.pb
#   inflating: step1_mouth_all/model.onnx
#   inflating: step1_mouth_all/model.tflite
#   inflating: step1_mouth_all/mouth_configuration.json
#   inflating: step1_mouth_all/neuralNetworkInputs.list
#   inflating: step1_mouth_all/neuralNetworkJoints.list
#   inflating: step1_mouth_all/neuralNetworkOutputs.list
#   inflating: step1_mouth_all/outputMaxima.csv
#   inflating: step1_mouth_all/outputMinima.csv
#   inflating: step1_mouth_all/outputOffsets.csv
#   inflating: step1_mouth_all/outputScalars.csv
#   inflating: step1_mouth_all/outputScalarsFraction.csv
#   inflating: step1_mouth_all/saved_model.pb
#   inflating: step1_mouth_all/summary.html
#  extracting: step1_reye_all/fingerprint.pb
#   inflating: step1_reye_all/keras_metadata.pb
#   inflating: step1_reye_all/model.onnx
#   inflating: step1_reye_all/model.tflite
#   inflating: step1_reye_all/neuralNetworkInputs.list
#   inflating: step1_reye_all/neuralNetworkJoints.list
#   inflating: step1_reye_all/neuralNetworkOutputs.list
#   inflating: step1_reye_all/outputMaxima.csv
#   inflating: step1_reye_all/outputMinima.csv
#   inflating: step1_reye_all/outputOffsets.csv
#   inflating: step1_reye_all/outputScalars.csv
#   inflating: step1_reye_all/outputScalarsFraction.csv
#   inflating: step1_reye_all/reye_configuration.json
#   inflating: step1_reye_all/saved_model.pb
#   inflating: step1_reye_all/summary.html
#  extracting: step1_upperbody_all/fingerprint.pb
#   inflating: step1_upperbody_all/keras_metadata.pb
#   inflating: step1_upperbody_all/model.onnx
#   inflating: step1_upperbody_all/model.tflite
#   inflating: step1_upperbody_all/neuralNetworkInputs.list
#   inflating: step1_upperbody_all/neuralNetworkJoints.list
#   inflating: step1_upperbody_all/neuralNetworkOutputs.list
#   inflating: step1_upperbody_all/outputMaxima.csv
#   inflating: step1_upperbody_all/outputMinima.csv
#   inflating: step1_upperbody_all/outputOffsets.csv
#   inflating: step1_upperbody_all/outputScalars.csv
#   inflating: step1_upperbody_all/outputScalarsFraction.csv
#   inflating: step1_upperbody_all/saved_model.pb
#   inflating: step1_upperbody_all/summary.html
#   inflating: step1_upperbody_all/upperbody_all.pca
#   inflating: step1_upperbody_all/upperbody_configuration.json
# --2025-04-06 00:26:02--  http://ammar.gr/mocapnet/mnet4/mediapipe.zip
# Resolving ammar.gr (ammar.gr)... 139.91.185.16
# Connecting to ammar.gr (ammar.gr)|139.91.185.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34375605 (33M) [application/zip]
# Saving to: ‘mediapipe.zip’
#
# mediapipe.zip       100%[===================>]  32.78M  8.47MB/s    in 4.3s
#
# 2025-04-06 00:26:07 (7.64 MB/s) - ‘mediapipe.zip’ saved [34375605/34375605]
#
# Archive:  mediapipe.zip
#   inflating: movenet/variables/variables.data-00000-of-00001
#   inflating: movenet/variables/variables.index
#   inflating: handnet/full/hand_landmark.tflite
#   inflating: handnet/full/palm_detection.tflite
#   inflating: handnet/lite/hand_landmark.tflite
#   inflating: handnet/lite/palm_detection.tflite
#   inflating: movenet/body.png
#   inflating: movenet/lite-model_movenet_singlepose_lightning_tflite_int8_4.tflite
#   inflating: movenet/model.onnx
#   inflating: movenet/saved_model.pb
#   inflating: handnet/hand_landmarks.png
#   inflating: handnet/test2.mkv
#   inflating: handnet/test.mkv
# Ready for use
# From now on to work with MocapNET you can use :
# source pythonVirtualEnvironment/bin/activate
# !python3 -m mediapipeHolisticWebcamMocapNET --from webcam  --save --plot
#  OR
# !python3 -m mediapipeHolisticWebcamMocapNET --from shuffle.webm --save --plot
#  OR
# !python3 -m csvNET --from ../../../dataset/sample.csv  --save --plot
#
#  if you are running on collab don't forget to append --headless to your command
#  after the run is complete out.bvh will contain your results
# JIT Python/C Compilation *made by AmmarTM* handled by :
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# Intel Optimizations available and will be used
# MocapNET setup is finished, you can run the next cell now..

# %%
#<----- Click to get a video from the internet and then track it ( e.g. shuffle.webm )

#You can also upload your own by clicking the Files icon and using the menu on the left
#You need to put files in the /content/MocapNET/src/python/mnet4/ directory

#Make sure we are at the correct directory
import os
if (not os.path.isfile("mediapipeHolisticWebcamMocapNET.py")):
    os.chdir("MocapNET/src/python/mnet4")

# !wget http://ammar.gr/mocapnet/shuffle.webm -O shuffle.webm

#Analyze the file shuffle.web through MediaPipe 2D + MocapNET 3D Pose Estimation!
!(python3 -m mediapipeHolisticWebcamMocapNET --from shuffle.webm --ik 0.001 99 99 --smooth 60 10 --all --save --plot --headless 2> /dev/null)
print("MocapNET video input processing finished, you can run the next cells now to see the results..")

#Outputs are :
#livelastRun3DHiRes.mp4 | A video showing the regressed output overlayed on RGB
#livelastPlot3DHiRes.mp4| A video plot of the retrieved BVH degrees of freedom
#out.bvh                | the extracted BVH file
#2d_out.csv             | Input 2D joints used by MocapNET as a CSV file
#3d_out.csv             | Output 3D joints produced by MocapNET as a CSV file
#bvh_out.csv            | Output BVH angles produced by MocapNET as a CSV file
# Out:
# --2025-04-06 00:26:13--  http://ammar.gr/mocapnet/shuffle.webm
# Resolving ammar.gr (ammar.gr)... 139.91.185.16
# Connecting to ammar.gr (ammar.gr)|139.91.185.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13390229 (13M) [video/webm]
# Saving to: ‘shuffle.webm’
#
# shuffle.webm        100%[===================>]  12.77M  4.69MB/s    in 2.7s
#
# 2025-04-06 00:26:16 (4.69 MB/s) - ‘shuffle.webm’ saved [13390229/13390229]
#
#
#  ██████╗ ███╗   ██╗███╗   ██╗██╗  ██╗
# ██╔═══██╗████╗  ██║████╗  ██║╚██╗██╔╝
# ██║   ██║██╔██╗ ██║██╔██╗ ██║ ╚███╔╝
# ██║   ██║██║╚██╗██║██║╚██╗██║ ██╔██╗
# ╚██████╔╝██║ ╚████║██║ ╚████║██╔╝ ██╗
#  ╚═════╝ ╚═╝  ╚═══╝╚═╝  ╚═══╝╚═╝  ╚═╝
#  Loading  mouth ..
# Rescaling early stopping delta from  0.001
# To an early stopping delta of  0.0025
# Will use automatically selected randomization function (old code)
# ONNX devices available :  CPU
# ONNX INPUTS  input_all
# List :  step1_mouth_all/neuralNetworkInputs.list  has  528  elements
# List :  step1_mouth_all/neuralNetworkJoints.list  has  66  elements
# List :  step1_mouth_all/neuralNetworkOutputs.list  has  44  elements
# CSV file : step1_mouth_all/outputOffsets.csv ..
#
# Counting number of lines in file  step1_mouth_all/outputOffsets.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.0037030935287475585  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.0  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.0  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -1.65  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  0.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  0.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  0.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  0.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  0.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  0.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  0.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  -0.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  0.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  0.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  0.5  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  -0.5  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  0.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  -15.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  0.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  -15.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  8.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  0.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  -15.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  15.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  0.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  0.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# CSV file : step1_mouth_all/outputScalarsFraction.csv ..
#
# Counting number of lines in file  step1_mouth_all/outputScalarsFraction.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.0037129918734232583  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.096  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.04  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  0.26  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  8.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  8.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  8.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  0.4  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  0.4  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  0.4  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  0.4  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  0.4  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.4  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  0.4  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  0.4  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.4  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  0.4  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  3.6  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  3.6  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  3.4  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  3.4  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  12.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  6.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  12.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  6.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  4.8  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  6.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  6.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  6.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  12.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  12.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  0.4  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  0.4  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  0.4  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  0.4  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  0.4  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  0.4  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  0.4  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  0.4  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  0.4  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  0.4  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  0.4  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  0.4  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  0.4  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  0.4  <->  oris05_yrotation
# CSV file : step1_mouth_all/outputMinima.csv ..
#
# Counting number of lines in file  step1_mouth_all/outputMinima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.003738554318745931  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  -0.24  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  -0.1  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -2.3  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  -20.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  -20.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  -20.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  0.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  0.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  0.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  0.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  -0.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  -9.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  -9.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  -8.0  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  -9.0  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  -30.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  -30.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  -30.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  -30.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  -4.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  -15.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  -30.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  0.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  -30.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  -30.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# CSV file : step1_mouth_all/outputMaxima.csv ..
#
# Counting number of lines in file  step1_mouth_all/outputMaxima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.0035993576049804686  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.24  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.1  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -1.0  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  20.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  20.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  20.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  0.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  0.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  0.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  0.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  -0.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  9.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  9.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  9.0  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  8.0  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  30.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  -0.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  30.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  -0.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  20.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  15.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  -0.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  30.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  30.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  30.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# Output Mapping :
# Out hip_xposition|Min -0.24|Max 0.24|Scalar 0.10|Offset 0.00
# Out hip_yposition|Min -0.10|Max 0.10|Scalar 0.04|Offset 0.00
# Out hip_zposition|Min -2.30|Max -1.00|Scalar 0.26|Offset -1.65
# Out neck1_zrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out neck1_xrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out neck1_yrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out eye.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out eye.r_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out eye.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out eye.l_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oculi01.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oculi01.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis03.r_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis04.r_xrotation|Min -0.00|Max -0.00|Scalar 0.40|Offset -0.00
# Out orbicularis03.l_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis04.l_xrotation|Min -0.00|Max -0.00|Scalar 0.40|Offset -0.00
# Out levator06.l_xrotation|Min -9.00|Max 9.00|Scalar 3.60|Offset 0.00
# Out levator06.r_xrotation|Min -9.00|Max 9.00|Scalar 3.60|Offset 0.00
# Out levator03.l_zrotation|Min -8.00|Max 9.00|Scalar 3.40|Offset 0.50
# Out levator03.r_zrotation|Min -9.00|Max 8.00|Scalar 3.40|Offset -0.50
# Out oris03.l_zrotation|Min -30.00|Max 30.00|Scalar 12.00|Offset 0.00
# Out oris07.l_zrotation|Min -30.00|Max -0.00|Scalar 6.00|Offset -15.00
# Out oris03.r_zrotation|Min -30.00|Max 30.00|Scalar 12.00|Offset 0.00
# Out oris07.r_zrotation|Min -30.00|Max -0.00|Scalar 6.00|Offset -15.00
# Out jaw_xrotation|Min -4.00|Max 20.00|Scalar 4.80|Offset 8.00
# Out jaw_yrotation|Min -15.00|Max 15.00|Scalar 6.00|Offset 0.00
# Out oris04.l_zrotation|Min -30.00|Max -0.00|Scalar 6.00|Offset -15.00
# Out oris04.r_zrotation|Min 0.00|Max 30.00|Scalar 6.00|Offset 15.00
# Out oris06.l_zrotation|Min -30.00|Max 30.00|Scalar 12.00|Offset 0.00
# Out oris06.r_zrotation|Min -30.00|Max 30.00|Scalar 12.00|Offset 0.00
# Out orbicularis03.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out orbicularis04.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out orbicularis03.l_yrotation|Min -172.00|Max -172.00|Scalar 0.40|Offset -172.00
# Out orbicularis04.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out levator06.l_yrotation|Min -247.00|Max -247.00|Scalar 0.40|Offset -247.00
# Out levator06.r_yrotation|Min 247.00|Max 247.00|Scalar 0.40|Offset 247.00
# Out oris03.l_xrotation|Min -40.00|Max -40.00|Scalar 0.40|Offset -40.00
# Out oris03.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris07.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris03.r_xrotation|Min -40.00|Max -40.00|Scalar 0.40|Offset -40.00
# Out oris03.r_yrotation|Min 179.00|Max 179.00|Scalar 0.40|Offset 179.00
# Out oris07.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris05_xrotation|Min -35.00|Max -35.00|Scalar 0.40|Offset -35.00
# Out oris05_yrotation|Min -176.00|Max -176.00|Scalar 0.40|Offset -176.00
# initializeDecompositionForExecutionEngine
# Number of Channels Per NSDM element  1
#
#
#
# Inputs : ['2dx_head_nostrills_2', '2dy_head_nostrills_2', 'visible_head_nostrills_2', '2dx_head_chin', '2dy_head_chin', 'visible_head_chin', '2dx_head_outmouth_0', '2dy_head_outmouth_0', 'visible_head_outmouth_0', '2dx_head_outmouth_1', '2dy_head_outmouth_1', 'visible_head_outmouth_1', '2dx_head_outmouth_2', '2dy_head_outmouth_2', 'visible_head_outmouth_2', '2dx_head_outmouth_3', '2dy_head_outmouth_3', 'visible_head_outmouth_3', '2dx_head_outmouth_4', '2dy_head_outmouth_4', 'visible_head_outmouth_4', '2dx_head_outmouth_5', '2dy_head_outmouth_5', 'visible_head_outmouth_5', '2dx_head_outmouth_6', '2dy_head_outmouth_6', 'visible_head_outmouth_6', '2dx_head_outmouth_7', '2dy_head_outmouth_7', 'visible_head_outmouth_7', '2dx_head_outmouth_8', '2dy_head_outmouth_8', 'visible_head_outmouth_8', '2dx_head_outmouth_9', '2dy_head_outmouth_9', 'visible_head_outmouth_9', '2dx_head_outmouth_10', '2dy_head_outmouth_10', 'visible_head_outmouth_10', '2dx_head_outmouth_11', '2dy_head_outmouth_11', 'visible_head_outmouth_11', '2dx_head_inmouth_0', '2dy_head_inmouth_0', 'visible_head_inmouth_0', '2dx_head_inmouth_1', '2dy_head_inmouth_1', 'visible_head_inmouth_1', '2dx_head_inmouth_2', '2dy_head_inmouth_2', 'visible_head_inmouth_2', '2dx_head_inmouth_3', '2dy_head_inmouth_3', 'visible_head_inmouth_3', '2dx_head_inmouth_4', '2dy_head_inmouth_4', 'visible_head_inmouth_4', '2dx_head_inmouth_5', '2dy_head_inmouth_5', 'visible_head_inmouth_5', '2dx_head_inmouth_6', '2dy_head_inmouth_6', 'visible_head_inmouth_6', '2dx_head_inmouth_7', '2dy_head_inmouth_7', 'visible_head_inmouth_7']
# Outputs : ['hip_xposition', 'hip_yposition', 'hip_zposition', 'neck1_zrotation', 'neck1_xrotation', 'neck1_yrotation', 'eye.r_zrotation', 'eye.r_xrotation', 'eye.l_zrotation', 'eye.l_xrotation', 'oculi01.r_zrotation', 'oculi01.l_zrotation', 'orbicularis03.r_xrotation', 'orbicularis04.r_xrotation', 'orbicularis03.l_xrotation', 'orbicularis04.l_xrotation', 'levator06.l_xrotation', 'levator06.r_xrotation', 'levator03.l_zrotation', 'levator03.r_zrotation', 'oris03.l_zrotation', 'oris07.l_zrotation', 'oris03.r_zrotation', 'oris07.r_zrotation', 'jaw_xrotation', 'jaw_yrotation', 'oris04.l_zrotation', 'oris04.r_zrotation', 'oris06.l_zrotation', 'oris06.r_zrotation', 'orbicularis03.r_yrotation', 'orbicularis04.r_yrotation', 'orbicularis03.l_yrotation', 'orbicularis04.l_yrotation', 'levator06.l_yrotation', 'levator06.r_yrotation', 'oris03.l_xrotation', 'oris03.l_yrotation', 'oris07.l_yrotation', 'oris03.r_xrotation', 'oris03.r_yrotation', 'oris07.r_yrotation', 'oris05_xrotation', 'oris05_yrotation']
#  Loading  reye ..
# Rescaling early stopping delta from  0.001
# To an early stopping delta of  0.0025
# Will use automatically selected randomization function (old code)
# ONNX devices available :  CPU
# ONNX INPUTS  input_all
# List :  step1_reye_all/neuralNetworkInputs.list  has  360  elements
# List :  step1_reye_all/neuralNetworkJoints.list  has  45  elements
# List :  step1_reye_all/neuralNetworkOutputs.list  has  44  elements
# CSV file : step1_reye_all/outputOffsets.csv ..
#
# Counting number of lines in file  step1_reye_all/outputOffsets.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.0034544785817464192  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.0  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.0  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -1.65  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  0.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  0.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  0.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  3.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  3.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  0.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  0.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  0.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  0.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  0.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  0.0  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  -0.0  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  0.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  0.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  0.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  0.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  8.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  0.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  0.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  0.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  0.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  0.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# CSV file : step1_reye_all/outputScalarsFraction.csv ..
#
# Counting number of lines in file  step1_reye_all/outputScalarsFraction.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.003619114557902018  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.096  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.04  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  0.26  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  8.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  8.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  12.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  18.144001  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  5.2  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  18.144001  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  5.2  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  8.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.4  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  6.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  6.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.4  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  0.4  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  0.4  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  0.4  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  0.4  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  0.4  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  0.4  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  0.4  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  0.4  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  0.4  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  4.8  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  6.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  0.4  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  0.4  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  0.4  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  0.4  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  0.4  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  0.4  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  0.4  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  0.4  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  0.4  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  0.4  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  0.4  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  0.4  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  0.4  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  0.4  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  0.4  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  0.4  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  0.4  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  0.4  <->  oris05_yrotation
# CSV file : step1_reye_all/outputMinima.csv ..
#
# Counting number of lines in file  step1_reye_all/outputMinima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.0037001371383666992  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  -0.24  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  -0.1  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -2.3  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  -20.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  -20.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  -30.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  -45.36  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  -10.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  -45.36  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  -10.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  -20.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  -15.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  -15.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  0.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  0.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  0.0  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  -0.0  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  0.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  0.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  0.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  0.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  -4.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  -15.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  0.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  0.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  0.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  0.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# CSV file : step1_reye_all/outputMaxima.csv ..
#
# Counting number of lines in file  step1_reye_all/outputMaxima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  44
#  Input file on disk has a shape of [ 1 , 44 ]
#  Input we will read has a shape of [ 1 , 44 ]
#  Input will occupy  176.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 44)
# GPU Size Occupied by data =  1.6391277313232422e-07  GB
#
# Time elapsed :  0.00379940668741862  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  0.24  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  0.1  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -1.0  <->  hip_zposition
# outputOffsets  3 / 3  <->  neck1_Zrotation  <->  20.0  <->  neck1_zrotation
# outputOffsets  4 / 4  <->  neck1_Xrotation  <->  20.0  <->  neck1_xrotation
# outputOffsets  5 / 5  <->  neck1_Yrotation  <->  30.0  <->  neck1_yrotation
# outputOffsets  6 / 6  <->  eye.R_Zrotation  <->  45.36  <->  eye.r_zrotation
# outputOffsets  7 / 7  <->  eye.R_Xrotation  <->  16.0  <->  eye.r_xrotation
# outputOffsets  8 / 8  <->  eye.L_Zrotation  <->  45.36  <->  eye.l_zrotation
# outputOffsets  9 / 9  <->  eye.L_Xrotation  <->  16.0  <->  eye.l_xrotation
# outputOffsets  10 / 10  <->  oculi01.R_Zrotation  <->  20.0  <->  oculi01.r_zrotation
# outputOffsets  11 / 11  <->  oculi01.L_Zrotation  <->  0.0  <->  oculi01.l_zrotation
# outputOffsets  12 / 12  <->  orbicularis03.R_Xrotation  <->  15.0  <->  orbicularis03.r_xrotation
# outputOffsets  13 / 13  <->  orbicularis04.R_Xrotation  <->  15.0  <->  orbicularis04.r_xrotation
# outputOffsets  14 / 14  <->  orbicularis03.L_Xrotation  <->  0.0  <->  orbicularis03.l_xrotation
# outputOffsets  15 / 15  <->  orbicularis04.L_Xrotation  <->  -0.0  <->  orbicularis04.l_xrotation
# outputOffsets  16 / 16  <->  levator06.L_Xrotation  <->  0.0  <->  levator06.l_xrotation
# outputOffsets  17 / 17  <->  levator06.R_Xrotation  <->  0.0  <->  levator06.r_xrotation
# outputOffsets  18 / 18  <->  levator03.L_Zrotation  <->  0.0  <->  levator03.l_zrotation
# outputOffsets  19 / 19  <->  levator03.R_Zrotation  <->  -0.0  <->  levator03.r_zrotation
# outputOffsets  20 / 20  <->  oris03.L_Zrotation  <->  0.0  <->  oris03.l_zrotation
# outputOffsets  21 / 21  <->  oris07.L_Zrotation  <->  0.0  <->  oris07.l_zrotation
# outputOffsets  22 / 22  <->  oris03.R_Zrotation  <->  0.0  <->  oris03.r_zrotation
# outputOffsets  23 / 23  <->  oris07.R_Zrotation  <->  0.0  <->  oris07.r_zrotation
# outputOffsets  24 / 24  <->  jaw_Xrotation  <->  20.0  <->  jaw_xrotation
# outputOffsets  25 / 25  <->  jaw_Yrotation  <->  15.0  <->  jaw_yrotation
# outputOffsets  26 / 26  <->  oris04.L_Zrotation  <->  0.0  <->  oris04.l_zrotation
# outputOffsets  27 / 27  <->  oris04.R_Zrotation  <->  0.0  <->  oris04.r_zrotation
# outputOffsets  28 / 28  <->  oris06.L_Zrotation  <->  0.0  <->  oris06.l_zrotation
# outputOffsets  29 / 29  <->  oris06.R_Zrotation  <->  0.0  <->  oris06.r_zrotation
# outputOffsets  30 / 30  <->  orbicularis03.R_Yrotation  <->  172.0  <->  orbicularis03.r_yrotation
# outputOffsets  31 / 31  <->  orbicularis04.R_Yrotation  <->  172.0  <->  orbicularis04.r_yrotation
# outputOffsets  32 / 32  <->  orbicularis03.L_Yrotation  <->  -172.0  <->  orbicularis03.l_yrotation
# outputOffsets  33 / 33  <->  orbicularis04.L_Yrotation  <->  172.0  <->  orbicularis04.l_yrotation
# outputOffsets  34 / 34  <->  levator06.L_Yrotation  <->  -247.0  <->  levator06.l_yrotation
# outputOffsets  35 / 35  <->  levator06.R_Yrotation  <->  247.0  <->  levator06.r_yrotation
# outputOffsets  36 / 36  <->  oris03.L_Xrotation  <->  -40.0  <->  oris03.l_xrotation
# outputOffsets  37 / 37  <->  oris03.L_Yrotation  <->  172.0  <->  oris03.l_yrotation
# outputOffsets  38 / 38  <->  oris07.L_Yrotation  <->  172.0  <->  oris07.l_yrotation
# outputOffsets  39 / 39  <->  oris03.R_Xrotation  <->  -40.0  <->  oris03.r_xrotation
# outputOffsets  40 / 40  <->  oris03.R_Yrotation  <->  179.0  <->  oris03.r_yrotation
# outputOffsets  41 / 41  <->  oris07.R_Yrotation  <->  172.0  <->  oris07.r_yrotation
# outputOffsets  42 / 42  <->  oris05_Xrotation  <->  -35.0  <->  oris05_xrotation
# outputOffsets  43 / 43  <->  oris05_Yrotation  <->  -176.0  <->  oris05_yrotation
# Output Mapping :
# Out hip_xposition|Min -0.24|Max 0.24|Scalar 0.10|Offset 0.00
# Out hip_yposition|Min -0.10|Max 0.10|Scalar 0.04|Offset 0.00
# Out hip_zposition|Min -2.30|Max -1.00|Scalar 0.26|Offset -1.65
# Out neck1_zrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out neck1_xrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out neck1_yrotation|Min -30.00|Max 30.00|Scalar 12.00|Offset 0.00
# Out eye.r_zrotation|Min -45.36|Max 45.36|Scalar 18.14|Offset 0.00
# Out eye.r_xrotation|Min -10.00|Max 16.00|Scalar 5.20|Offset 3.00
# Out eye.l_zrotation|Min -45.36|Max 45.36|Scalar 18.14|Offset 0.00
# Out eye.l_xrotation|Min -10.00|Max 16.00|Scalar 5.20|Offset 3.00
# Out oculi01.r_zrotation|Min -20.00|Max 20.00|Scalar 8.00|Offset 0.00
# Out oculi01.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis03.r_xrotation|Min -15.00|Max 15.00|Scalar 6.00|Offset 0.00
# Out orbicularis04.r_xrotation|Min -15.00|Max 15.00|Scalar 6.00|Offset 0.00
# Out orbicularis03.l_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis04.l_xrotation|Min -0.00|Max -0.00|Scalar 0.40|Offset -0.00
# Out levator06.l_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out levator06.r_xrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out levator03.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out levator03.r_zrotation|Min -0.00|Max -0.00|Scalar 0.40|Offset -0.00
# Out oris03.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris07.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris03.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris07.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out jaw_xrotation|Min -4.00|Max 20.00|Scalar 4.80|Offset 8.00
# Out jaw_yrotation|Min -15.00|Max 15.00|Scalar 6.00|Offset 0.00
# Out oris04.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris04.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris06.l_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out oris06.r_zrotation|Min 0.00|Max 0.00|Scalar 0.40|Offset 0.00
# Out orbicularis03.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out orbicularis04.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out orbicularis03.l_yrotation|Min -172.00|Max -172.00|Scalar 0.40|Offset -172.00
# Out orbicularis04.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out levator06.l_yrotation|Min -247.00|Max -247.00|Scalar 0.40|Offset -247.00
# Out levator06.r_yrotation|Min 247.00|Max 247.00|Scalar 0.40|Offset 247.00
# Out oris03.l_xrotation|Min -40.00|Max -40.00|Scalar 0.40|Offset -40.00
# Out oris03.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris07.l_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris03.r_xrotation|Min -40.00|Max -40.00|Scalar 0.40|Offset -40.00
# Out oris03.r_yrotation|Min 179.00|Max 179.00|Scalar 0.40|Offset 179.00
# Out oris07.r_yrotation|Min 172.00|Max 172.00|Scalar 0.40|Offset 172.00
# Out oris05_xrotation|Min -35.00|Max -35.00|Scalar 0.40|Offset -35.00
# Out oris05_yrotation|Min -176.00|Max -176.00|Scalar 0.40|Offset -176.00
# initializeDecompositionForExecutionEngine
# Number of Channels Per NSDM element  1
#
#
#
# Inputs : ['2dx_head_reye_0', '2dy_head_reye_0', 'visible_head_reye_0', '2dx_head_reye_1', '2dy_head_reye_1', 'visible_head_reye_1', '2dx_head_reye_2', '2dy_head_reye_2', 'visible_head_reye_2', '2dx_head_reye_3', '2dy_head_reye_3', 'visible_head_reye_3', '2dx_head_reye_4', '2dy_head_reye_4', 'visible_head_reye_4', '2dx_head_reye_5', '2dy_head_reye_5', 'visible_head_reye_5', '2dx_head_nostrills_2', '2dy_head_nostrills_2', 'visible_head_nostrills_2', '2dx_head_rchin_0', '2dy_head_rchin_0', 'visible_head_rchin_0', '2dx_head_chin', '2dy_head_chin', 'visible_head_chin', '2dx_head_reyebrow_0', '2dy_head_reyebrow_0', 'visible_head_reyebrow_0', '2dx_head_reyebrow_1', '2dy_head_reyebrow_1', 'visible_head_reyebrow_1', '2dx_head_reyebrow_2', '2dy_head_reyebrow_2', 'visible_head_reyebrow_2', '2dx_head_reyebrow_3', '2dy_head_reyebrow_3', 'visible_head_reyebrow_3', '2dx_head_reyebrow_4', '2dy_head_reyebrow_4', 'visible_head_reyebrow_4', '2dx_head_reye', '2dy_head_reye', 'visible_head_reye']
# Outputs : ['hip_xposition', 'hip_yposition', 'hip_zposition', 'neck1_zrotation', 'neck1_xrotation', 'neck1_yrotation', 'eye.r_zrotation', 'eye.r_xrotation', 'eye.l_zrotation', 'eye.l_xrotation', 'oculi01.r_zrotation', 'oculi01.l_zrotation', 'orbicularis03.r_xrotation', 'orbicularis04.r_xrotation', 'orbicularis03.l_xrotation', 'orbicularis04.l_xrotation', 'levator06.l_xrotation', 'levator06.r_xrotation', 'levator03.l_zrotation', 'levator03.r_zrotation', 'oris03.l_zrotation', 'oris07.l_zrotation', 'oris03.r_zrotation', 'oris07.r_zrotation', 'jaw_xrotation', 'jaw_yrotation', 'oris04.l_zrotation', 'oris04.r_zrotation', 'oris06.l_zrotation', 'oris06.r_zrotation', 'orbicularis03.r_yrotation', 'orbicularis04.r_yrotation', 'orbicularis03.l_yrotation', 'orbicularis04.l_yrotation', 'levator06.l_yrotation', 'levator06.r_yrotation', 'oris03.l_xrotation', 'oris03.l_yrotation', 'oris07.l_yrotation', 'oris03.r_xrotation', 'oris03.r_yrotation', 'oris07.r_yrotation', 'oris05_xrotation', 'oris05_yrotation']
#
#
#
# Inputs that need to be subtracted from one :  {'2dx_head_reye_0': '2dx_head_leye_3', '2dx_head_reye_1': '2dx_head_leye_2', '2dx_head_reye_2': '2dx_head_leye_1', '2dx_head_reye_3': '2dx_head_leye_0', '2dx_head_reye_4': '2dx_head_leye_5', '2dx_head_reye_5': '2dx_head_leye_4', '2dx_head_nostrills_2': '2dx_head_nostrills_2', '2dx_head_rchin_0': '2dx_head_lchin_0', '2dx_head_chin': '2dx_head_chin', '2dx_head_reyebrow_0': '2dx_head_leyebrow_0', '2dx_head_reyebrow_1': '2dx_head_leyebrow_1', '2dx_head_reyebrow_2': '2dx_head_leyebrow_2', '2dx_head_reyebrow_3': '2dx_head_leyebrow_3', '2dx_head_reyebrow_4': '2dx_head_leyebrow_4', '2dx_head_reye': '2dx_head_leye'}
#
#
#
# ...
# outputOffsets  11 / 11  <->  chest_Yrotation  <->  25.54698  <->  chest_yrotation
# outputOffsets  12 / 12  <->  neck1_Zrotation  <->  13.333327  <->  neck1_zrotation
# outputOffsets  13 / 13  <->  neck1_Xrotation  <->  13.333327  <->  neck1_xrotation
# outputOffsets  14 / 14  <->  neck1_Yrotation  <->  33.333282  <->  neck1_yrotation
# outputOffsets  15 / 15  <->  head_Zrotation  <->  0.666667  <->  head_zrotation
# outputOffsets  16 / 16  <->  head_Xrotation  <->  0.666667  <->  head_xrotation
# outputOffsets  17 / 17  <->  head_Yrotation  <->  0.666667  <->  head_yrotation
# outputOffsets  18 / 18  <->  eye.l_Zrotation  <->  0.666667  <->  eye.l_zrotation
# outputOffsets  19 / 19  <->  eye.l_Xrotation  <->  0.666667  <->  eye.l_xrotation
# outputOffsets  20 / 20  <->  eye.l_Yrotation  <->  0.666667  <->  eye.l_yrotation
# outputOffsets  21 / 21  <->  eye.r_Zrotation  <->  0.666667  <->  eye.r_zrotation
# outputOffsets  22 / 22  <->  eye.r_Xrotation  <->  0.666667  <->  eye.r_xrotation
# outputOffsets  23 / 23  <->  eye.r_Yrotation  <->  0.666667  <->  eye.r_yrotation
# outputOffsets  24 / 24  <->  rshoulder_Zrotation  <->  129.7743  <->  rshoulder_zrotation
# outputOffsets  25 / 25  <->  rshoulder_Xrotation  <->  68.84707  <->  rshoulder_xrotation
# outputOffsets  26 / 26  <->  rshoulder_Yrotation  <->  129.6454  <->  rshoulder_yrotation
# outputOffsets  27 / 27  <->  relbow_Zrotation  <->  28.922993  <->  relbow_zrotation
# outputOffsets  28 / 28  <->  relbow_Xrotation  <->  26.636538  <->  relbow_xrotation
# outputOffsets  29 / 29  <->  relbow_Yrotation  <->  91.84965  <->  relbow_yrotation
# outputOffsets  30 / 30  <->  rhand_Zrotation  <->  59.453808  <->  rhand_zrotation
# outputOffsets  31 / 31  <->  rhand_Xrotation  <->  58.216335  <->  rhand_xrotation
# outputOffsets  32 / 32  <->  rhand_Yrotation  <->  119.99934  <->  rhand_yrotation
# outputOffsets  33 / 33  <->  lshoulder_Zrotation  <->  129.7546  <->  lshoulder_zrotation
# outputOffsets  34 / 34  <->  lshoulder_Xrotation  <->  69.30432  <->  lshoulder_xrotation
# outputOffsets  35 / 35  <->  lshoulder_Yrotation  <->  129.74979  <->  lshoulder_yrotation
# outputOffsets  36 / 36  <->  lelbow_Zrotation  <->  21.282883  <->  lelbow_zrotation
# outputOffsets  37 / 37  <->  lelbow_Xrotation  <->  26.007221  <->  lelbow_xrotation
# outputOffsets  38 / 38  <->  lelbow_Yrotation  <->  60.0191  <->  lelbow_yrotation
# outputOffsets  39 / 39  <->  lhand_Zrotation  <->  59.861492  <->  lhand_zrotation
# outputOffsets  40 / 40  <->  lhand_Xrotation  <->  58.914497  <->  lhand_xrotation
# outputOffsets  41 / 41  <->  lhand_Yrotation  <->  119.99999  <->  lhand_yrotation
# CSV file : step1_upperbody_all/outputMinima.csv ..
#
# Counting number of lines in file  step1_upperbody_all/outputMinima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  42
#  Input file on disk has a shape of [ 1 , 42 ]
#  Input we will read has a shape of [ 1 , 42 ]
#  Input will occupy  168.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 42)
# GPU Size Occupied by data =  1.564621925354004e-07  GB
#
# Time elapsed :  0.0033774614334106446  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  -529.2313  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  -207.79399  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -449.99988  <->  hip_zposition
# outputOffsets  3 / 3  <->  hip_Zrotation  <->  -24.99989  <->  hip_zrotation
# outputOffsets  4 / 4  <->  hip_Yrotation  <->  -159.99997  <->  hip_yrotation
# outputOffsets  5 / 5  <->  hip_Xrotation  <->  -24.99998  <->  hip_xrotation
# outputOffsets  6 / 6  <->  abdomen_Zrotation  <->  -178.20413  <->  abdomen_zrotation
# outputOffsets  7 / 7  <->  abdomen_Xrotation  <->  -87.1576  <->  abdomen_xrotation
# outputOffsets  8 / 8  <->  abdomen_Yrotation  <->  -177.82033  <->  abdomen_yrotation
# outputOffsets  9 / 9  <->  chest_Zrotation  <->  -63.75615  <->  chest_zrotation
# outputOffsets  10 / 10  <->  chest_Xrotation  <->  -62.9506  <->  chest_xrotation
# outputOffsets  11 / 11  <->  chest_Yrotation  <->  -37.28359  <->  chest_yrotation
# outputOffsets  12 / 12  <->  neck1_Zrotation  <->  -20.0  <->  neck1_zrotation
# outputOffsets  13 / 13  <->  neck1_Xrotation  <->  -20.0  <->  neck1_xrotation
# outputOffsets  14 / 14  <->  neck1_Yrotation  <->  -49.99996  <->  neck1_yrotation
# outputOffsets  15 / 15  <->  head_Zrotation  <->  0.0  <->  head_zrotation
# outputOffsets  16 / 16  <->  head_Xrotation  <->  0.0  <->  head_xrotation
# outputOffsets  17 / 17  <->  head_Yrotation  <->  0.0  <->  head_yrotation
# outputOffsets  18 / 18  <->  eye.l_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  19 / 19  <->  eye.l_Xrotation  <->  0.0  <->  eye.l_xrotation
# outputOffsets  20 / 20  <->  eye.l_Yrotation  <->  0.0  <->  eye.l_yrotation
# outputOffsets  21 / 21  <->  eye.r_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  22 / 22  <->  eye.r_Xrotation  <->  0.0  <->  eye.r_xrotation
# outputOffsets  23 / 23  <->  eye.r_Yrotation  <->  0.0  <->  eye.r_yrotation
# outputOffsets  24 / 24  <->  rshoulder_Zrotation  <->  -194.7987  <->  rshoulder_zrotation
# outputOffsets  25 / 25  <->  rshoulder_Xrotation  <->  -102.29043  <->  rshoulder_xrotation
# outputOffsets  26 / 26  <->  rshoulder_Yrotation  <->  -194.36276  <->  rshoulder_yrotation
# outputOffsets  27 / 27  <->  relbow_Zrotation  <->  -50.37946  <->  relbow_zrotation
# outputOffsets  28 / 28  <->  relbow_Xrotation  <->  -68.60764  <->  relbow_xrotation
# outputOffsets  29 / 29  <->  relbow_Yrotation  <->  -110.44964  <->  relbow_yrotation
# outputOffsets  30 / 30  <->  rhand_Zrotation  <->  -170.935  <->  rhand_zrotation
# outputOffsets  31 / 31  <->  rhand_Xrotation  <->  -88.4084  <->  rhand_xrotation
# outputOffsets  32 / 32  <->  rhand_Yrotation  <->  -179.998  <->  rhand_yrotation
# outputOffsets  33 / 33  <->  lshoulder_Zrotation  <->  -194.5943  <->  lshoulder_zrotation
# outputOffsets  34 / 34  <->  lshoulder_Xrotation  <->  -103.43016  <->  lshoulder_xrotation
# outputOffsets  35 / 35  <->  lshoulder_Yrotation  <->  -194.86687  <->  lshoulder_yrotation
# outputOffsets  36 / 36  <->  lelbow_Zrotation  <->  -14.32072  <->  lelbow_zrotation
# outputOffsets  37 / 37  <->  lelbow_Xrotation  <->  -68.62555  <->  lelbow_xrotation
# outputOffsets  38 / 38  <->  lelbow_Yrotation  <->  -163.74974  <->  lelbow_yrotation
# outputOffsets  39 / 39  <->  lhand_Zrotation  <->  -7.17449  <->  lhand_zrotation
# outputOffsets  40 / 40  <->  lhand_Xrotation  <->  -88.1337  <->  lhand_xrotation
# outputOffsets  41 / 41  <->  lhand_Yrotation  <->  -180.0  <->  lhand_yrotation
# CSV file : step1_upperbody_all/outputMaxima.csv ..
#
# Counting number of lines in file  step1_upperbody_all/outputMaxima.csv
#  Input file has  1  training samples
#
# Number of Input elements :  42
#  Input file on disk has a shape of [ 1 , 42 ]
#  Input we will read has a shape of [ 1 , 42 ]
#  Input will occupy  168.0 bytes  of RAM
#
# Stopping reading file to obey memory limit given by parameter --mem  1.0
#
#
#  read, Samples:  1 , was expecting  1  samples
#
# (1, 42)
# GPU Size Occupied by data =  1.564621925354004e-07  GB
#
# Time elapsed :  0.003397039572397868  mins
# outputOffsets  0 / 0  <->  hip_Xposition  <->  530.11707  <->  hip_xposition
# outputOffsets  1 / 1  <->  hip_Yposition  <->  208.53902  <->  hip_yposition
# outputOffsets  2 / 2  <->  hip_Zposition  <->  -90.00186  <->  hip_zposition
# outputOffsets  3 / 3  <->  hip_Zrotation  <->  25.0  <->  hip_zrotation
# outputOffsets  4 / 4  <->  hip_Yrotation  <->  159.99994  <->  hip_yrotation
# outputOffsets  5 / 5  <->  hip_Xrotation  <->  24.99996  <->  hip_xrotation
# outputOffsets  6 / 6  <->  abdomen_Zrotation  <->  178.90823  <->  abdomen_zrotation
# outputOffsets  7 / 7  <->  abdomen_Xrotation  <->  91.66096  <->  abdomen_xrotation
# outputOffsets  8 / 8  <->  abdomen_Yrotation  <->  177.81322  <->  abdomen_yrotation
# outputOffsets  9 / 9  <->  chest_Zrotation  <->  62.50187  <->  chest_zrotation
# outputOffsets  10 / 10  <->  chest_Xrotation  <->  41.13868  <->  chest_xrotation
# outputOffsets  11 / 11  <->  chest_Yrotation  <->  39.35735  <->  chest_yrotation
# outputOffsets  12 / 12  <->  neck1_Zrotation  <->  19.99998  <->  neck1_zrotation
# outputOffsets  13 / 13  <->  neck1_Xrotation  <->  19.99998  <->  neck1_xrotation
# outputOffsets  14 / 14  <->  neck1_Yrotation  <->  49.99989  <->  neck1_yrotation
# outputOffsets  15 / 15  <->  head_Zrotation  <->  0.0  <->  head_zrotation
# outputOffsets  16 / 16  <->  head_Xrotation  <->  0.0  <->  head_xrotation
# outputOffsets  17 / 17  <->  head_Yrotation  <->  0.0  <->  head_yrotation
# outputOffsets  18 / 18  <->  eye.l_Zrotation  <->  0.0  <->  eye.l_zrotation
# outputOffsets  19 / 19  <->  eye.l_Xrotation  <->  0.0  <->  eye.l_xrotation
# outputOffsets  20 / 20  <->  eye.l_Yrotation  <->  0.0  <->  eye.l_yrotation
# outputOffsets  21 / 21  <->  eye.r_Zrotation  <->  0.0  <->  eye.r_zrotation
# outputOffsets  22 / 22  <->  eye.r_Xrotation  <->  0.0  <->  eye.r_xrotation
# outputOffsets  23 / 23  <->  eye.r_Yrotation  <->  0.0  <->  eye.r_yrotation
# outputOffsets  24 / 24  <->  rshoulder_Zrotation  <->  194.52423  <->  rshoulder_zrotation
# outputOffsets  25 / 25  <->  rshoulder_Xrotation  <->  104.25081  <->  rshoulder_xrotation
# outputOffsets  26 / 26  <->  rshoulder_Yrotation  <->  194.57347  <->  rshoulder_yrotation
# outputOffsets  27 / 27  <->  relbow_Zrotation  <->  36.38952  <->  relbow_zrotation
# outputOffsets  28 / 28  <->  relbow_Xrotation  <->  11.30196  <->  relbow_xrotation
# outputOffsets  29 / 29  <->  relbow_Yrotation  <->  165.0993  <->  relbow_yrotation
# outputOffsets  30 / 30  <->  rhand_Zrotation  <->  7.42642  <->  rhand_zrotation
# outputOffsets  31 / 31  <->  rhand_Xrotation  <->  86.2406  <->  rhand_xrotation
# outputOffsets  32 / 32  <->  rhand_Yrotation  <->  180.0  <->  rhand_yrotation
# outputOffsets  33 / 33  <->  lshoulder_Zrotation  <->  194.66948  <->  lshoulder_zrotation
# outputOffsets  34 / 34  <->  lshoulder_Xrotation  <->  104.48281  <->  lshoulder_xrotation
# outputOffsets  35 / 35  <->  lshoulder_Yrotation  <->  194.3825  <->  lshoulder_yrotation
# outputOffsets  36 / 36  <->  lelbow_Zrotation  <->  49.52793  <->  lelbow_zrotation
# outputOffsets  37 / 37  <->  lelbow_Xrotation  <->  9.39612  <->  lelbow_xrotation
# outputOffsets  38 / 38  <->  lelbow_Yrotation  <->  16.30756  <->  lelbow_yrotation
# outputOffsets  39 / 39  <->  lhand_Zrotation  <->  172.41  <->  lhand_zrotation
# outputOffsets  40 / 40  <->  lhand_Xrotation  <->  88.6098  <->  lhand_xrotation
# outputOffsets  41 / 41  <->  lhand_Yrotation  <->  180.0  <->  lhand_yrotation
# Output Mapping :
# Out hip_xposition|Min -529.23|Max 530.12|Scalar 353.12|Offset 0.44
# Out hip_yposition|Min -207.79|Max 208.54|Scalar 138.78|Offset 0.37
# Out hip_zposition|Min -450.00|Max -90.00|Scalar 120.00|Offset -270.00
# Out hip_zrotation|Min -25.00|Max 25.00|Scalar 16.67|Offset 0.00
# Out hip_yrotation|Min -160.00|Max 160.00|Scalar 106.67|Offset -0.00
# Out hip_xrotation|Min -25.00|Max 25.00|Scalar 16.67|Offset -0.00
# Out abdomen_zrotation|Min -178.20|Max 178.91|Scalar 119.04|Offset 0.35
# Out abdomen_xrotation|Min -87.16|Max 91.66|Scalar 59.61|Offset 2.25
# Out abdomen_yrotation|Min -177.82|Max 177.81|Scalar 118.54|Offset -0.00
# Out chest_zrotation|Min -63.76|Max 62.50|Scalar 42.09|Offset -0.63
# Out chest_xrotation|Min -62.95|Max 41.14|Scalar 34.70|Offset -10.91
# Out chest_yrotation|Min -37.28|Max 39.36|Scalar 25.55|Offset 1.04
# Out neck1_zrotation|Min -20.00|Max 20.00|Scalar 13.33|Offset -0.00
# Out neck1_xrotation|Min -20.00|Max 20.00|Scalar 13.33|Offset -0.00
# Out neck1_yrotation|Min -50.00|Max 50.00|Scalar 33.33|Offset -0.00
# Out head_zrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out head_xrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out head_yrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.l_zrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.l_xrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.l_yrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.r_zrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.r_xrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out eye.r_yrotation|Min 0.00|Max 0.00|Scalar 0.67|Offset 0.00
# Out rshoulder_zrotation|Min -194.80|Max 194.52|Scalar 129.77|Offset -0.14
# Out rshoulder_xrotation|Min -102.29|Max 104.25|Scalar 68.85|Offset 0.98
# Out rshoulder_yrotation|Min -194.36|Max 194.57|Scalar 129.65|Offset 0.11
# Out relbow_zrotation|Min -50.38|Max 36.39|Scalar 28.92|Offset -6.99
# Out relbow_xrotation|Min -68.61|Max 11.30|Scalar 26.64|Offset -28.65
# Out relbow_yrotation|Min -110.45|Max 165.10|Scalar 91.85|Offset 27.32
# Out rhand_zrotation|Min -170.93|Max 7.43|Scalar 59.45|Offset -81.75
# Out rhand_xrotation|Min -88.41|Max 86.24|Scalar 58.22|Offset -1.08
# Out rhand_yrotation|Min -180.00|Max 180.00|Scalar 120.00|Offset 0.00
# Out lshoulder_zrotation|Min -194.59|Max 194.67|Scalar 129.75|Offset 0.04
# Out lshoulder_xrotation|Min -103.43|Max 104.48|Scalar 69.30|Offset 0.53
# Out lshoulder_yrotation|Min -194.87|Max 194.38|Scalar 129.75|Offset -0.24
# Out lelbow_zrotation|Min -14.32|Max 49.53|Scalar 21.28|Offset 17.60
# Out lelbow_xrotation|Min -68.63|Max 9.40|Scalar 26.01|Offset -29.61
# Out lelbow_yrotation|Min -163.75|Max 16.31|Scalar 60.02|Offset -73.72
# Out lhand_zrotation|Min -7.17|Max 172.41|Scalar 59.86|Offset 82.62
# Out lhand_xrotation|Min -88.13|Max 88.61|Scalar 58.91|Offset 0.24
# Out lhand_yrotation|Min -180.00|Max 180.00|Scalar 120.00|Offset 0.00
# initializeDecompositionForExecutionEngine
# Number of Channels Per NSDM element  1
#
#
#
# Inputs : ['2dx_hip', '2dy_hip', 'visible_hip', '2dx_neck1', '2dy_neck1', 'visible_neck1', '2dx_head', '2dy_head', 'visible_head', '2dx_endsite_eye.l', '2dy_endsite_eye.l', 'visible_endsite_eye.l', '2dx_endsite_eye.r', '2dy_endsite_eye.r', 'visible_endsite_eye.r', '2dx_rshoulder', '2dy_rshoulder', 'visible_rshoulder', '2dx_relbow', '2dy_relbow', 'visible_relbow', '2dx_rhand', '2dy_rhand', 'visible_rhand', '2dx_lshoulder', '2dy_lshoulder', 'visible_lshoulder', '2dx_lelbow', '2dy_lelbow', 'visible_lelbow', '2dx_lhand', '2dy_lhand', 'visible_lhand']
# Outputs : ['hip_xposition', 'hip_yposition', 'hip_zposition', 'hip_zrotation', 'hip_yrotation', 'hip_xrotation', 'abdomen_zrotation', 'abdomen_xrotation', 'abdomen_yrotation', 'chest_zrotation', 'chest_xrotation', 'chest_yrotation', 'neck1_zrotation', 'neck1_xrotation', 'neck1_yrotation', 'head_zrotation', 'head_xrotation', 'head_yrotation', 'eye.l_zrotation', 'eye.l_xrotation', 'eye.l_yrotation', 'eye.r_zrotation', 'eye.r_xrotation', 'eye.r_yrotation', 'rshoulder_zrotation', 'rshoulder_xrotation', 'rshoulder_yrotation', 'relbow_zrotation', 'relbow_xrotation', 'relbow_yrotation', 'rhand_zrotation', 'rhand_xrotation', 'rhand_yrotation', 'lshoulder_zrotation', 'lshoulder_xrotation', 'lshoulder_yrotation', 'lelbow_zrotation', 'lelbow_xrotation', 'lelbow_yrotation', 'lhand_zrotation', 'lhand_xrotation', 'lhand_yrotation']
# ONNX has no model parameters calculator
# ONNX has no model parameters calculator
# ONNX has no model parameters calculator
# ONNX has no model parameters calculator
# ONNX has no model parameters calculator
#  Combined  network has  0  parameters..
#  Loading C/Python libraries..
# Initializing BVH file  BVH/headerWithHeadAndOneMotion.bvh  from  BVH/libBVHConverter.so
# Caching networks :
# Testing loaded  mouth  model
# Testing loaded  reye  model
# Testing loaded  leye  model
# Testing loaded  lhand  model
# Testing loaded  rhand  model
# Testing loaded  lowerbody  model
# Testing loaded  upperbody  model
#  MocapNET ready for use!
# Testing loaded  mouth  model
# Testing loaded  reye  model
# Testing loaded  leye  model
# Testing loaded  lhand  model
# Testing loaded  rhand  model
# Testing loaded  lowerbody  model
# Testing loaded  upperbody  model
#
#
#
#
# Starting MocapNET using MediaPipe 2D Joint Estimator Input
# Please wait until input processing finishes!
# Your MocapNET version is up to date
# Frame 333|onnx|MPJPE 6.8 px|2D NN:14.9Hz|MocapNET:15.0Hz|HCD:7.4Hz

# %%
#<----- Click to run a sign-language dataset without mediapipe from a dumped Openpose/JSON/CSV source

#Make sure we are at the correct directory
import os
if (not os.path.isfile("csvNET.py")):
    os.chdir("MocapNET/src/python/mnet4")

#Download a single sign (con0014) from SIGNUM
# !wget http://ammar.gr/datasets/signumtest.zip -O signumtest.zip
# !unzip -o signumtest.zip

#Analyze the file con0014/2dJoints_v1.4.csv through MediaPipe 2D + MocapNET 3D Pose Estimation!
!(python3 -m csvNET --from con0014/2dJoints_v1.4.csv --ik 0.001 99 99 --upperbody --reye --mouth --hands --save --plot --headless 2> /dev/null)
print("MocapNET video input processing finished, you can run the next cells now to see the results..")

# %%
#<----- Click to see the generated BVH angle plot of the last MocapNET run!
from IPython.display import Video
import os
if (not os.path.isfile("livelastPlot3DHiRes.mp4")):
   print("Please execute the previous cells and wait for them to complete before seeing this visualization!")
   exit

Video("livelastPlot3DHiRes.mp4",embed=True)

# %%
#<----- Click to see the generated visualization of the last MocapNET run!
from IPython.display import Video
import os
if (not os.path.isfile("livelastRun3DHiRes.mp4")):
   print("Please execute the previous cells and wait for them to complete before seeing this visualization!")
   exit

Video("livelastRun3DHiRes.mp4",embed=True)

# %%
#<----- Click to download the generated BVH/3D files of the last MocapNET run!
import os
from google.colab import files
if (not os.path.isfile("out.bvh")) or (not os.path.isfile("2d_out.csv")) or (not os.path.isfile("bvh_out.csv")) or (not os.path.isfile("3d_out.csv")):
    print("Please execute the previous cells and wait for them to complete before downloading output!")
else:
    print("Download Output Files!")
    files.download("out.bvh")
    files.download("2d_out.csv")
    files.download("3d_out.csv")
    files.download("bvh_out.csv")
#To render the 3D face get Blender from https://www.blender.org/
#Download http://ammar.gr/mocapnet/mnet4/face.blend and open it using Blender
#Download http://ammar.gr/mocapnet/mnet4/headerWithHeadAndOneMotion.bvh and open it using Blender at a 0.01 scale
#Run The Loaded Python Script
#Click on the armature and on the menu right click the orange rectangle
#Select headerWithHeadAndOneMotion as Source BVH
#Select newgirl as Target Obj
#Select a directory as a target for generated dataset
#Select the path to the regressed bvh_out.csv to load pre-generated dataset
#Click Just Render CSV Dataset

# %%
#<----- Click to attempt MocapNET live demo by streaming your camera to Google Colab
#EXPERIMENTAL, performance is impacted because of low image throughput!

import cv2
import os
from colabStream import init_camera,take_frame,show_frame


from mediapipeHolisticWebcamMocapNET import MediaPipeHolistic
from MocapNET import easyMocapNETConstructor
from folderStream import resize_with_padding

# Create instances of MediaPipeHolistic and MocapNET
mp_holistic = MediaPipeHolistic(doMediapipeVisualization=False)
mnet = easyMocapNETConstructor(
    engine              = "onnx",
    doProfiling         = False,
    multiThreaded       = False,
    doHCDPostProcessing = True,
    hcdLearningRate     = 0.001,
    hcdEpochs           = 99,
    hcdIterations       = 99,
    bvhScale            = 1.0,
    doBody              = True,
    doFace              = False,
    doREye              = True,
    doMouth             = True,
    doHands             = True,
    addNoise            = 0.0
)


# init JavaScript code
init_camera()

while True:
    try:
        image = take_frame()

        image = resize_with_padding(image,1280,720)

        # Perform image processing with MediaPipeHolistic
        mocapNETInput, annotated_image = mp_holistic.convertImageToMocapNETInput(image)

        # Perform 3D joint prediction with MocapNET
        mocapNET3DOutput = mnet.predict3DJoints(mocapNETInput)

        # Visualize the results on the image
        #image_with_results = Image.fromarray(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))

        from MocapNETVisualization import visualizeMocapNETEnsemble
        image,plotImage = visualizeMocapNETEnsemble(mnet,annotated_image,plotBVHChannels=False)

        show_frame(annotated_image)  # it replace previous image

    except Exception as err:
        print('Exception:', err)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fc9e3eaf639c> in <cell line: 0>()
#       7
#       8
# ----> 9 from mediapipeHolisticWebcamMocapNET import MediaPipeHolistic
#      10 from MocapNET import easyMocapNETConstructor
#      11 from folderStream import resize_with_padding
#
# /content/MocapNET/src/python/mnet4/mediapipeHolisticWebcamMocapNET.py in <module>
#      10
#      11 import cv2
# ---> 12 import mediapipe as mp
#      13 import numpy as np
#      14 import time
#
# /usr/local/lib/python3.11/dist-packages/mediapipe/__init__.py in <module>
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      18
#      19
#
# /usr/local/lib/python3.11/dist-packages/mediapipe/tasks/python/__init__.py in <module>
#      15 """MediaPipe Tasks API."""
#      16
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# /usr/local/lib/python3.11/dist-packages/mediapipe/tasks/python/audio/__init__.py in <module>
#      25 AudioEmbedderOptions = audio_embedder.AudioEmbedderOptions
#      26 AudioEmbedderResult = audio_embedder.AudioEmbedderResult
# ---> 27 RunningMode = core.audio_task_running_mode.AudioTaskRunningMode
#      28
#      29 # Remove unnecessary modules to avoid duplication in API docs.
#
# NameError: name 'core' is not defined

# %%
# !pip uninstall -y numpy
# !pip cache purge

# %%
# !pip install numpy==1.23.5 --no-cache-dir --force-reinstall

# %%
# !pip uninstall -y mediapipe
# !pip install mediapipe==0.10.3
# Out:
# Found existing installation: mediapipe 0.10.11
# Uninstalling mediapipe-0.10.11:
#   Successfully uninstalled mediapipe-0.10.11
# ERROR: Could not find a version that satisfies the requirement mediapipe==0.10.3 (from versions: 0.10.5, 0.10.7, 0.10.8, 0.10.9, 0.10.10, 0.10.11, 0.10.13, 0.10.14, 0.10.15, 0.10.18, 0.10.20, 0.10.21)
# ERROR: No matching distribution found for mediapipe==0.10.3

# %%
# !pip uninstall mediapipe protobuf absl-py -y

# !pip install protobuf==3.20.3 absl-py==1.4.0

# !pip install mediapipe==0.10.8
# Out:
# Found existing installation: mediapipe 0.10.8
# Uninstalling mediapipe-0.10.8:
#   Successfully uninstalled mediapipe-0.10.8
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3
# Found existing installation: absl-py 1.4.0
# Uninstalling absl-py-1.4.0:
#   Successfully uninstalled absl-py-1.4.0
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting absl-py==1.4.0
#   Using cached absl_py-1.4.0-py3-none-any.whl.metadata (2.3 kB)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Installing collected packages: protobuf, absl-py
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# Successfully installed absl-py-1.4.0 protobuf-3.20.3
# Collecting mediapipe==0.10.8
#   Using cached mediapipe-0.10.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (25.2.10)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe==0.10.8) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.8) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe==0.10.8) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.8) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.8) (1.17.0)
# Using cached mediapipe-0.10.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# Installing collected packages: mediapipe
# Successfully installed mediapipe-0.10.8

# %%
# !pip uninstall mediapipe
# !pip install mediapipe
# Out:
# Found existing installation: mediapipe 0.10.21
# Uninstalling mediapipe-0.10.21:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/mediapipe-0.10.21.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/mediapipe.libs/libEGL-48f73270.so.1.1.0
#     /usr/local/lib/python3.11/dist-packages/mediapipe.libs/libGLESv2-ed5eda4f.so.2.1.0
#     /usr/local/lib/python3.11/dist-packages/mediapipe.libs/libGLdispatch-64b28464.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/mediapipe/*
# Proceed (Y/n)? y
#   Successfully uninstalled mediapipe-0.10.21
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.1)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Using cached protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Using cached mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
# Using cached protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf2onnx 1.16.1 requires protobuf~=3.20, but you have protobuf 4.25.6 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# Successfully installed mediapipe-0.10.21 protobuf-4.25.6

# %%
# !pip install protobuf==3.20.3
# Out:
# Requirement already satisfied: protobuf==3.20.3 in /usr/local/lib/python3.11/dist-packages (3.20.3)

# %%
# !pip uninstall numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/lib/python3.11/dist-packages/numpy-1.26.4.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libopenblas64_p-r0-0cf96a72.3.23.dev.so
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4

# %%
y#D/L and compile a different version of MocapNET and evaluate it against CMUBVH test dataset
#Running this will take a while, but it is usefult to compare different trained MocapNET Models!
import os

#Download Test Set!
if (not os.path.isfile("dataset/generated/bvh_body_all_test.csv")):
   print("Downloading test set!")
   os.system("wget http://ammar.gr/datasets/testBody.zip && unzip testBody.zip")

#Download a different MocapNET build
# !python3 -m getModelFromDatabase --get 319 #<- change number to try a different version

#Do Evaluation
# !python3 -m evaluateMocapNET --config dataset/body_configuration.json --all body --skip 5 --engine onnx > lastEvaluationLog.txt
# !tail -n 30 lastEvaluationLog.txt

# %%
# %%HTML
# <!-- Activate this block to see a youtube video about rendering MocapNET results with Blender -->
# <iframe width="560" height="315" src="https://youtube.com/embed/ooLRUS5j4AI"></iframe>

# %%
"""

This library is provided under the FORTH license
https://github.com/FORTH-ModelBasedTracker/MocapNET/blob/master/license.txt

If you use this version of MocapNET for your research please consider citing :

@inproceedings{Qammaz2023b,
  author = {Qammaz, Ammar and Argyros, Antonis},
  title = {A Unified Approach for Occlusion Tolerant 3D Facial Pose Capture and Gaze Estimation using MocapNETs},
  booktitle = {International Conference on Computer Vision Workshops (AMFG 2023 - ICCVW 2023), (to appear)},
  publisher = {IEEE},
  year = {2023},
  month = {October},
  address = {Paris, France},
  projects =  {VMWARE,I.C.HUMANS},
  pdflink = {http://users.ics.forth.gr/ argyros/mypapers/2023_10_AMFG_Qammaz.pdf}
}

@inproceedings{Qammaz2021,
  author = {Qammaz, Ammar and Argyros, Antonis A},
  title = {Towards Holistic Real-time Human 3D Pose Estimation using MocapNETs},
  booktitle = {British Machine Vision Conference (BMVC 2021)},
  publisher = {BMVA},
  year = {2021},
  month = {November},
  projects =  {I.C.HUMANS},
  videolink = {https://www.youtube.com/watch?v=aaLOSY_p6Zc}
}
"""
